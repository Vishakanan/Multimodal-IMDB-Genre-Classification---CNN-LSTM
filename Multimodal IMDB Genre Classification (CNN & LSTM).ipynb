# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense
import seaborn as sns
from sklearn.metrics import multilabel_confusion_matrix
import textwrap

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
#         191.65M 100%    1.54MB/s    0:01:58 (xfr#7896, to-chk=0/7897)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/tmp/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [64, 64])
    return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

posters_train_ds = (
    list_posters_train_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .shuffle(1000)
    .batch(64)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

posters_valid_ds = (
    list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .batch(64)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.


overviews_train_ds = (list_overviews_train_ds.cache().shuffle(1000).batch(64).prefetch(tf.data.AUTOTUNE))

overviews_valid_ds = (list_overviews_valid_ds.cache().batch(64).prefetch(tf.data.AUTOTUNE))

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

VOCAB_SIZE = 10000

encoder = tf.keras.layers.TextVectorization(max_tokens=VOCAB_SIZE)

encoder.adapt(overviews_train_ds.map(lambda text, label: text))

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.

vocab = encoder.get_vocabulary()
print(vocab[:200])
# Out:
# ['', '[UNK]', np.str_('a'), np.str_('the'), np.str_('to'), np.str_('of'), np.str_('and'), np.str_('in'), np.str_('his'), np.str_('is'), np.str_('an'), np.str_('with'), np.str_('her'), np.str_('for'), np.str_('on'), np.str_('their'), np.str_('he'), np.str_('who'), np.str_('by'), np.str_('from'), np.str_('when'), np.str_('as'), np.str_('that'), np.str_('after'), np.str_('young'), np.str_('life'), np.str_('they'), np.str_('man'), np.str_('new'), np.str_('at'), np.str_('him'), np.str_('two'), np.str_('are'), np.str_('but'), np.str_('into'), np.str_('has'), np.str_('up'), np.str_('she'), np.str_('love'), np.str_('woman'), np.str_('family'), np.str_('out'), np.str_('one'), np.str_('find'), np.str_('it'), np.str_('be'), np.str_('must'), np.str_('friends'), np.str_('story'), np.str_('finds'), np.str_('school'), np.str_('them'), np.str_('world'), np.str_('group'), np.str_('about'), np.str_('where'), np.str_('while'), np.str_('father'), np.str_('have'), np.str_('girl'), np.str_('lives'), np.str_('years'), np.str_('wife'), np.str_('home'), np.str_('town'), np.str_('three'), np.str_('city'), np.str_('back'), np.str_('becomes'), np.str_('war'), np.str_('help'), np.str_('get'), np.str_('all'), np.str_('only'), np.str_('himself'), np.str_('during'), np.str_('high'), np.str_('york'), np.str_('boy'), np.str_('which'), np.str_('son'), np.str_('between'), np.str_('team'), np.str_('former'), np.str_('time'), np.str_('murder'), np.str_('gets'), np.str_('tries'), np.str_('american'), np.str_('against'), np.str_('falls'), np.str_('down'), np.str_('daughter'), np.str_('police'), np.str_('being'), np.str_('own'), np.str_('will'), np.str_('this'), np.str_('small'), np.str_('order'), np.str_('become'), np.str_('before'), np.str_('save'), np.str_('college'), np.str_('can'), np.str_('mother'), np.str_('its'), np.str_('takes'), np.str_('other'), np.str_('friend'), np.str_('take'), np.str_('death'), np.str_('together'), np.str_('set'), np.str_('way'), np.str_('was'), np.str_('over'), np.str_('old'), np.str_('through'), np.str_('goes'), np.str_('agent'), np.str_('husband'), np.str_('not'), np.str_('off'), np.str_('more'), np.str_('go'), np.str_('couple'), np.str_('people'), np.str_('killer'), np.str_('first'), np.str_('day'), np.str_('relationship'), np.str_('discovers'), np.str_('meets'), np.str_('each'), np.str_('brother'), np.str_('what'), np.str_('mysterious'), np.str_('men'), np.str_('house'), np.str_('now'), np.str_('make'), np.str_('been'), np.str_('us'), np.str_('forced'), np.str_('drug'), np.str_('cop'), np.str_('returns'), np.str_('hes'), np.str_('comes'), np.str_('begins'), np.str_('stop'), np.str_('parents'), np.str_('job'), np.str_('four'), np.str_('work'), np.str_('detective'), np.str_('best'), np.str_('secret'), np.str_('past'), np.str_('living'), np.str_('just'), np.str_('or'), np.str_('married'), np.str_('evil'), np.str_('trying'), np.str_('women'), np.str_('turns'), np.str_('student'), np.str_('most'), np.str_('soon'), np.str_('movie'), np.str_('discover'), np.str_('local'), np.str_('away'), np.str_('whose'), np.str_('film'), np.str_('try'), np.str_('than'), np.str_('series'), np.str_('children'), np.str_('so'), np.str_('fight'), np.str_('earth'), np.str_('another'), np.str_('live'), np.str_('killed'), np.str_('come'), np.str_('trip'), np.str_('teenage'), np.str_('sister'), np.str_('sent'), np.str_('around'), np.str_('search'), np.str_('then'), np.str_('some'), np.str_('run'), np.str_('night'), np.str_('last'), np.str_('brothers')]

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
  inputs = tf.keras.Input(shape=(64, 64, 3), name='Input')
  x = tf.keras.layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu', name='Conv0')(inputs)
  x = tf.keras.layers.Dropout(0.2, name='Drop1')(x)

  x = tf.keras.layers.Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv1')(x)
  x = tf.keras.layers.Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv2')(x)
  x = tf.keras.layers.Dropout(0.2, name='Drop2')(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=2, name='Pool1')(x)

  x = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv3')(x)
  x = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv4')(x)
  x = tf.keras.layers.Dropout(0.2, name='Drop3')(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=2, name='Pool2')(x)

  x = tf.keras.layers.Conv2D(128, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv5')(x)
  x = tf.keras.layers.Conv2D(128, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv6')(x)
  x = tf.keras.layers.Dropout(0.2, name='Drop4')(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=2, name='Pool3')(x)

  x = tf.keras.layers.Flatten(name='Flat')(x)
  x = tf.keras.layers.Dense(1024, activation='relu', name='FC1')(x)
  x = tf.keras.layers.Dropout(0.5, name='Drop5')(x)
  x = tf.keras.layers.Dense(1024, activation='relu', name='FC2')(x)
  x = tf.keras.layers.Dropout(0.5, name='Drop6')(x)

  outputs = tf.keras.layers.Dense(25, activation='sigmoid', name='Output')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs, name='model')
  return model

cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.

cnn_model.summary()
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv0 (Conv2D)                  │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop1 (Dropout)                 │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1 (Conv2D)                  │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2 (Conv2D)                  │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop2 (Dropout)                 │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool1 (MaxPooling2D)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv4 (Conv2D)                  │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop3 (Dropout)                 │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool2 (MaxPooling2D)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv5 (Conv2D)                  │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv6 (Conv2D)                  │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop4 (Dropout)                 │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3 (MaxPooling2D)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flat (Flatten)                  │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC1 (Dense)                     │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop5 (Dropout)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC2 (Dense)                     │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop6 (Dropout)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 25)             │        25,625 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
     metrics=[Precision(),Recall()]
)

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

embedder = tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()), output_dim=256, mask_zero=True)

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = tf.keras.Sequential([
    encoder,
    embedder,
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, return_sequences=True, dropout=0.5, recurrent_dropout=0.2)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.8),
    tf.keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.

lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization              │ (None, None)           │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, None, 256)      │     2,560,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, None, 512)      │     1,050,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

lstm_model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
     metrics=[Precision(),Recall()]
)

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    checkpoint_cnn_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

checkpoint_lstm_callback =  ModelCheckpoint(
    checkpoint_lstm_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.01))

lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    posters_train_ds,
    validation_data=posters_valid_ds,
    epochs=40,
    callbacks=[checkpoint_cnn_callback, lr_callback],
    verbose=1
)
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.4310 - precision: 0.2294 - recall: 0.2153
# Epoch 1: val_loss improved from inf to 0.32900, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 29s 170ms/step - loss: 0.4297 - precision: 0.2306 - recall: 0.2153 - val_loss: 0.3290 - val_precision: 0.5413 - val_recall: 0.2209 - learning_rate: 1.0000e-04
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2559 - precision: 0.4911 - recall: 0.2313
# Epoch 2: val_loss did not improve from 0.32900
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - loss: 0.2558 - precision: 0.4911 - recall: 0.2311 - val_loss: 0.3390 - val_precision: 0.5470 - val_recall: 0.2285 - learning_rate: 1.0000e-04
# Epoch 3/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2480 - precision: 0.4985 - recall: 0.2016
# Epoch 3: val_loss improved from 0.32900 to 0.32542, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.2480 - precision: 0.4989 - recall: 0.2019 - val_loss: 0.3254 - val_precision: 0.5696 - val_recall: 0.3567 - learning_rate: 1.0000e-04
# Epoch 4/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2390 - precision: 0.5459 - recall: 0.2491
# Epoch 4: val_loss improved from 0.32542 to 0.30114, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.2390 - precision: 0.5460 - recall: 0.2491 - val_loss: 0.3011 - val_precision: 0.5586 - val_recall: 0.3682 - learning_rate: 1.0000e-04
# Epoch 5/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2380 - precision: 0.5503 - recall: 0.2472
# Epoch 5: val_loss improved from 0.30114 to 0.29973, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.2380 - precision: 0.5505 - recall: 0.2473 - val_loss: 0.2997 - val_precision: 0.5799 - val_recall: 0.2890 - learning_rate: 1.0000e-04
# Epoch 6/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2330 - precision: 0.5801 - recall: 0.2618
# Epoch 6: val_loss improved from 0.29973 to 0.29180, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.2330 - precision: 0.5795 - recall: 0.2617 - val_loss: 0.2918 - val_precision: 0.5858 - val_recall: 0.3246 - learning_rate: 1.0000e-04
# Epoch 7/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2340 - precision: 0.5656 - recall: 0.2692
# Epoch 7: val_loss improved from 0.29180 to 0.27200, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2340 - precision: 0.5656 - recall: 0.2690 - val_loss: 0.2720 - val_precision: 0.5786 - val_recall: 0.3210 - learning_rate: 1.0000e-04
# Epoch 8/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2329 - precision: 0.5664 - recall: 0.2715
# Epoch 8: val_loss did not improve from 0.27200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.2328 - precision: 0.5668 - recall: 0.2714 - val_loss: 0.2826 - val_precision: 0.5803 - val_recall: 0.3223 - learning_rate: 1.0000e-04
# Epoch 9/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2309 - precision: 0.5783 - recall: 0.2819
# Epoch 9: val_loss did not improve from 0.27200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.2309 - precision: 0.5783 - recall: 0.2817 - val_loss: 0.2745 - val_precision: 0.5793 - val_recall: 0.3088 - learning_rate: 1.0000e-04
# Epoch 10/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2308 - precision: 0.5793 - recall: 0.2679
# Epoch 10: val_loss did not improve from 0.27200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.2308 - precision: 0.5794 - recall: 0.2679 - val_loss: 0.2823 - val_precision: 0.5700 - val_recall: 0.2797 - learning_rate: 1.0000e-04
# Epoch 11/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2294 - precision: 0.5884 - recall: 0.2862
# Epoch 11: val_loss improved from 0.27200 to 0.27017, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.2294 - precision: 0.5882 - recall: 0.2860 - val_loss: 0.2702 - val_precision: 0.6046 - val_recall: 0.2979 - learning_rate: 9.9005e-05
# Epoch 12/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2297 - precision: 0.5847 - recall: 0.2844
# Epoch 12: val_loss improved from 0.27017 to 0.26048, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2297 - precision: 0.5846 - recall: 0.2840 - val_loss: 0.2605 - val_precision: 0.5814 - val_recall: 0.2784 - learning_rate: 9.8020e-05
# Epoch 13/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2297 - precision: 0.5884 - recall: 0.2799
# Epoch 13: val_loss did not improve from 0.26048
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.2297 - precision: 0.5883 - recall: 0.2796 - val_loss: 0.2685 - val_precision: 0.5902 - val_recall: 0.3025 - learning_rate: 9.7045e-05
# Epoch 14/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2277 - precision: 0.5825 - recall: 0.2924
# Epoch 14: val_loss did not improve from 0.26048
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.2277 - precision: 0.5825 - recall: 0.2918 - val_loss: 0.2607 - val_precision: 0.5825 - val_recall: 0.3207 - learning_rate: 9.6079e-05
# Epoch 15/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2283 - precision: 0.5702 - recall: 0.2906
# Epoch 15: val_loss improved from 0.26048 to 0.25926, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.2283 - precision: 0.5706 - recall: 0.2903 - val_loss: 0.2593 - val_precision: 0.5830 - val_recall: 0.2969 - learning_rate: 9.5123e-05
# Epoch 16/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2265 - precision: 0.5911 - recall: 0.2889
# Epoch 16: val_loss did not improve from 0.25926
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.2266 - precision: 0.5914 - recall: 0.2885 - val_loss: 0.2603 - val_precision: 0.6061 - val_recall: 0.3018 - learning_rate: 9.4176e-05
# Epoch 17/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2267 - precision: 0.5941 - recall: 0.2827
# Epoch 17: val_loss improved from 0.25926 to 0.25574, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.2267 - precision: 0.5943 - recall: 0.2825 - val_loss: 0.2557 - val_precision: 0.5825 - val_recall: 0.2916 - learning_rate: 9.3239e-05
# Epoch 18/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2252 - precision: 0.6093 - recall: 0.2804
# Epoch 18: val_loss did not improve from 0.25574
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.2252 - precision: 0.6091 - recall: 0.2803 - val_loss: 0.2605 - val_precision: 0.6091 - val_recall: 0.2830 - learning_rate: 9.2312e-05
# Epoch 19/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2242 - precision: 0.6005 - recall: 0.2703
# Epoch 19: val_loss improved from 0.25574 to 0.25201, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.2243 - precision: 0.6005 - recall: 0.2704 - val_loss: 0.2520 - val_precision: 0.6040 - val_recall: 0.2474 - learning_rate: 9.1393e-05
# Epoch 20/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2244 - precision: 0.6105 - recall: 0.2800
# Epoch 20: val_loss improved from 0.25201 to 0.24738, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.2244 - precision: 0.6105 - recall: 0.2798 - val_loss: 0.2474 - val_precision: 0.5913 - val_recall: 0.2609 - learning_rate: 9.0484e-05
# Epoch 21/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2252 - precision: 0.6070 - recall: 0.2945
# Epoch 21: val_loss improved from 0.24738 to 0.24734, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.2251 - precision: 0.6072 - recall: 0.2940 - val_loss: 0.2473 - val_precision: 0.6082 - val_recall: 0.2794 - learning_rate: 8.9583e-05
# Epoch 22/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2238 - precision: 0.6114 - recall: 0.2798
# Epoch 22: val_loss did not improve from 0.24734
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.2238 - precision: 0.6115 - recall: 0.2798 - val_loss: 0.2500 - val_precision: 0.5987 - val_recall: 0.2523 - learning_rate: 8.8692e-05
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2226 - precision: 0.6198 - recall: 0.2816
# Epoch 23: val_loss improved from 0.24734 to 0.24513, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.2226 - precision: 0.6199 - recall: 0.2815 - val_loss: 0.2451 - val_precision: 0.5923 - val_recall: 0.2576 - learning_rate: 8.7810e-05
# Epoch 24/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2219 - precision: 0.6187 - recall: 0.2839
# Epoch 24: val_loss did not improve from 0.24513
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.2219 - precision: 0.6191 - recall: 0.2837 - val_loss: 0.2502 - val_precision: 0.6056 - val_recall: 0.2566 - learning_rate: 8.6936e-05
# Epoch 25/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2205 - precision: 0.6320 - recall: 0.2788
# Epoch 25: val_loss did not improve from 0.24513
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.2205 - precision: 0.6321 - recall: 0.2787 - val_loss: 0.2510 - val_precision: 0.5838 - val_recall: 0.2404 - learning_rate: 8.6071e-05
# Epoch 26/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2214 - precision: 0.6328 - recall: 0.2811
# Epoch 26: val_loss did not improve from 0.24513
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.2214 - precision: 0.6328 - recall: 0.2809 - val_loss: 0.2455 - val_precision: 0.5928 - val_recall: 0.2563 - learning_rate: 8.5214e-05
# Epoch 27/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2213 - precision: 0.6203 - recall: 0.2787
# Epoch 27: val_loss did not improve from 0.24513
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.2213 - precision: 0.6206 - recall: 0.2787 - val_loss: 0.2490 - val_precision: 0.5786 - val_recall: 0.2408 - learning_rate: 8.4366e-05
# Epoch 28/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2196 - precision: 0.6335 - recall: 0.2870
# Epoch 28: val_loss improved from 0.24513 to 0.23957, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.2196 - precision: 0.6336 - recall: 0.2868 - val_loss: 0.2396 - val_precision: 0.5944 - val_recall: 0.2589 - learning_rate: 8.3527e-05
# Epoch 29/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2185 - precision: 0.6427 - recall: 0.2938
# Epoch 29: val_loss did not improve from 0.23957
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.2185 - precision: 0.6426 - recall: 0.2935 - val_loss: 0.2415 - val_precision: 0.5773 - val_recall: 0.2381 - learning_rate: 8.2696e-05
# Epoch 30/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2181 - precision: 0.6548 - recall: 0.2765
# Epoch 30: val_loss did not improve from 0.23957
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.2181 - precision: 0.6548 - recall: 0.2766 - val_loss: 0.2455 - val_precision: 0.6656 - val_recall: 0.2675 - learning_rate: 8.1873e-05
# Epoch 31/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2242 - precision: 0.6148 - recall: 0.2619
# Epoch 31: val_loss did not improve from 0.23957
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.2241 - precision: 0.6154 - recall: 0.2622 - val_loss: 0.2453 - val_precision: 0.6023 - val_recall: 0.2421 - learning_rate: 8.1058e-05
# Epoch 32/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2181 - precision: 0.6530 - recall: 0.2835
# Epoch 32: val_loss improved from 0.23957 to 0.23525, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.2180 - precision: 0.6529 - recall: 0.2835 - val_loss: 0.2353 - val_precision: 0.6071 - val_recall: 0.2612 - learning_rate: 8.0252e-05
# Epoch 33/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2172 - precision: 0.6463 - recall: 0.2812
# Epoch 33: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.2172 - precision: 0.6465 - recall: 0.2811 - val_loss: 0.2413 - val_precision: 0.5941 - val_recall: 0.2480 - learning_rate: 7.9453e-05
# Epoch 34/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2168 - precision: 0.6588 - recall: 0.2913
# Epoch 34: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.2168 - precision: 0.6588 - recall: 0.2911 - val_loss: 0.2375 - val_precision: 0.5998 - val_recall: 0.2559 - learning_rate: 7.8663e-05
# Epoch 35/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2146 - precision: 0.6658 - recall: 0.2966
# Epoch 35: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.2147 - precision: 0.6656 - recall: 0.2963 - val_loss: 0.2354 - val_precision: 0.6083 - val_recall: 0.2625 - learning_rate: 7.7880e-05
# Epoch 36/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2151 - precision: 0.6591 - recall: 0.2862
# Epoch 36: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.2151 - precision: 0.6592 - recall: 0.2862 - val_loss: 0.2361 - val_precision: 0.6365 - val_recall: 0.2903 - learning_rate: 7.7105e-05
# Epoch 37/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2147 - precision: 0.6551 - recall: 0.2962
# Epoch 37: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.2147 - precision: 0.6553 - recall: 0.2959 - val_loss: 0.2365 - val_precision: 0.6136 - val_recall: 0.2559 - learning_rate: 7.6338e-05
# Epoch 38/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2138 - precision: 0.6651 - recall: 0.2962
# Epoch 38: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.2138 - precision: 0.6652 - recall: 0.2960 - val_loss: 0.2466 - val_precision: 0.5878 - val_recall: 0.2355 - learning_rate: 7.5578e-05
# Epoch 39/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2149 - precision: 0.6653 - recall: 0.2887
# Epoch 39: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.2148 - precision: 0.6654 - recall: 0.2886 - val_loss: 0.2448 - val_precision: 0.5835 - val_recall: 0.2365 - learning_rate: 7.4826e-05
# Epoch 40/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2116 - precision: 0.6647 - recall: 0.3014
# Epoch 40: val_loss did not improve from 0.23525
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.2117 - precision: 0.6649 - recall: 0.3010 - val_loss: 0.2413 - val_precision: 0.6274 - val_recall: 0.2480 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.
lstm_history = lstm_model.fit(
    overviews_train_ds,
    validation_data=overviews_valid_ds,
    epochs=20,
    callbacks=[checkpoint_lstm_callback, lr_callback],
    verbose=1
)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.6638 - precision_1: 0.1114 - recall_1: 0.3895
# Epoch 1: val_loss improved from inf to 0.34297, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 801ms/step - loss: 0.6631 - precision_1: 0.1115 - recall_1: 0.3889 - val_loss: 0.3430 - val_precision_1: 0.4367 - val_recall_1: 0.1823 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - loss: 0.4555 - precision_1: 0.1843 - recall_1: 0.3254
# Epoch 2: val_loss improved from 0.34297 to 0.28200, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 802ms/step - loss: 0.4553 - precision_1: 0.1844 - recall_1: 0.3253 - val_loss: 0.2820 - val_precision_1: 0.5443 - val_recall_1: 0.2090 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - loss: 0.3992 - precision_1: 0.2183 - recall_1: 0.2894
# Epoch 3: val_loss improved from 0.28200 to 0.26112, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 61s 761ms/step - loss: 0.3991 - precision_1: 0.2184 - recall_1: 0.2893 - val_loss: 0.2611 - val_precision_1: 0.5460 - val_recall_1: 0.2256 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - loss: 0.3629 - precision_1: 0.2560 - recall_1: 0.2747
# Epoch 4: val_loss improved from 0.26112 to 0.25299, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 778ms/step - loss: 0.3629 - precision_1: 0.2560 - recall_1: 0.2746 - val_loss: 0.2530 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - loss: 0.3438 - precision_1: 0.2871 - recall_1: 0.2629
# Epoch 5: val_loss improved from 0.25299 to 0.24812, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 781ms/step - loss: 0.3438 - precision_1: 0.2872 - recall_1: 0.2628 - val_loss: 0.2481 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - loss: 0.3280 - precision_1: 0.3207 - recall_1: 0.2563
# Epoch 6: val_loss improved from 0.24812 to 0.24517, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 803ms/step - loss: 0.3280 - precision_1: 0.3207 - recall_1: 0.2562 - val_loss: 0.2452 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - loss: 0.3196 - precision_1: 0.3347 - recall_1: 0.2415
# Epoch 7: val_loss improved from 0.24517 to 0.24391, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 786ms/step - loss: 0.3195 - precision_1: 0.3348 - recall_1: 0.2415 - val_loss: 0.2439 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.3097 - precision_1: 0.3545 - recall_1: 0.2314
# Epoch 8: val_loss improved from 0.24391 to 0.24173, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 777ms/step - loss: 0.3097 - precision_1: 0.3546 - recall_1: 0.2314 - val_loss: 0.2417 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - loss: 0.3004 - precision_1: 0.3774 - recall_1: 0.2323
# Epoch 9: val_loss improved from 0.24173 to 0.24110, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 789ms/step - loss: 0.3004 - precision_1: 0.3774 - recall_1: 0.2322 - val_loss: 0.2411 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.2965 - precision_1: 0.3939 - recall_1: 0.2338
# Epoch 10: val_loss improved from 0.24110 to 0.23992, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 62s 781ms/step - loss: 0.2965 - precision_1: 0.3939 - recall_1: 0.2338 - val_loss: 0.2399 - val_precision_1: 0.5470 - val_recall_1: 0.2285 - learning_rate: 1.0000e-04
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.2891 - precision_1: 0.4014 - recall_1: 0.2218
# Epoch 11: val_loss improved from 0.23992 to 0.23928, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 776ms/step - loss: 0.2891 - precision_1: 0.4014 - recall_1: 0.2217 - val_loss: 0.2393 - val_precision_1: 0.5475 - val_recall_1: 0.2285 - learning_rate: 9.9005e-05
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - loss: 0.2862 - precision_1: 0.4183 - recall_1: 0.2234
# Epoch 12: val_loss improved from 0.23928 to 0.23785, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 790ms/step - loss: 0.2861 - precision_1: 0.4183 - recall_1: 0.2234 - val_loss: 0.2378 - val_precision_1: 0.5471 - val_recall_1: 0.2282 - learning_rate: 9.8020e-05
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - loss: 0.2798 - precision_1: 0.4326 - recall_1: 0.2262
# Epoch 13: val_loss improved from 0.23785 to 0.23695, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 80s 763ms/step - loss: 0.2798 - precision_1: 0.4326 - recall_1: 0.2261 - val_loss: 0.2369 - val_precision_1: 0.5475 - val_recall_1: 0.2282 - learning_rate: 9.7045e-05
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - loss: 0.2764 - precision_1: 0.4354 - recall_1: 0.2261
# Epoch 14: val_loss improved from 0.23695 to 0.23515, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 788ms/step - loss: 0.2764 - precision_1: 0.4355 - recall_1: 0.2261 - val_loss: 0.2351 - val_precision_1: 0.5541 - val_recall_1: 0.2249 - learning_rate: 9.6079e-05
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - loss: 0.2723 - precision_1: 0.4457 - recall_1: 0.2289
# Epoch 15: val_loss improved from 0.23515 to 0.23314, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 786ms/step - loss: 0.2723 - precision_1: 0.4458 - recall_1: 0.2289 - val_loss: 0.2331 - val_precision_1: 0.5708 - val_recall_1: 0.2503 - learning_rate: 9.5123e-05
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - loss: 0.2677 - precision_1: 0.4736 - recall_1: 0.2408
# Epoch 16: val_loss improved from 0.23314 to 0.23007, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 61s 769ms/step - loss: 0.2677 - precision_1: 0.4736 - recall_1: 0.2408 - val_loss: 0.2301 - val_precision_1: 0.6134 - val_recall_1: 0.2421 - learning_rate: 9.4176e-05
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - loss: 0.2613 - precision_1: 0.4854 - recall_1: 0.2451
# Epoch 17: val_loss improved from 0.23007 to 0.22852, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 783ms/step - loss: 0.2613 - precision_1: 0.4855 - recall_1: 0.2451 - val_loss: 0.2285 - val_precision_1: 0.6039 - val_recall_1: 0.2583 - learning_rate: 9.3239e-05
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - loss: 0.2561 - precision_1: 0.5109 - recall_1: 0.2643
# Epoch 18: val_loss improved from 0.22852 to 0.22760, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 80s 756ms/step - loss: 0.2561 - precision_1: 0.5107 - recall_1: 0.2642 - val_loss: 0.2276 - val_precision_1: 0.6046 - val_recall_1: 0.2807 - learning_rate: 9.2312e-05
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - loss: 0.2543 - precision_1: 0.5149 - recall_1: 0.2617
# Epoch 19: val_loss improved from 0.22760 to 0.22739, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 765ms/step - loss: 0.2543 - precision_1: 0.5149 - recall_1: 0.2617 - val_loss: 0.2274 - val_precision_1: 0.5983 - val_recall_1: 0.2873 - learning_rate: 9.1393e-05
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - loss: 0.2500 - precision_1: 0.5164 - recall_1: 0.2648
# Epoch 20: val_loss improved from 0.22739 to 0.22508, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 61s 758ms/step - loss: 0.2500 - precision_1: 0.5164 - recall_1: 0.2647 - val_loss: 0.2251 - val_precision_1: 0.6216 - val_recall_1: 0.2447 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i

#Complete here

# Load best model weights
cnn_model.load_weights(checkpoint_cnn_filepath)

def plot_training_history(history):
    plt.figure(figsize=(14, 4))

    plt.subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Binary Crossentropy Loss')
    plt.legend()

    # Plot Precision
    plt.subplot(1, 3, 2)
    plt.plot(history.history['precision'], label='Train Precision')
    plt.plot(history.history['val_precision'], label='Validation Precision')
    plt.title('Precision over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.legend()

    # Plot Recall
    plt.subplot(1, 3, 3)
    plt.plot(history.history['recall'], label='Train Recall')
    plt.plot(history.history['val_recall'], label='Validation Recall')
    plt.title('Recall over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training_history(cnn_history)

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i

#Complete here

# Load best weights
lstm_model.load_weights(checkpoint_lstm_filepath)


def plot_lstm_training_history(history):
    plt.figure(figsize=(14, 4))

    # Loss
    plt.subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Binary Crossentropy Loss')
    plt.legend()

    # Precision
    plt.subplot(1, 3, 2)
    plt.plot(history.history['precision_1'], label='Train Precision')
    plt.plot(history.history['val_precision_1'], label='Validation Precision')
    plt.title('Precision over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.legend()

    # Recall
    plt.subplot(1, 3, 3)
    plt.plot(history.history['recall_1'], label='Train Recall')
    plt.plot(history.history['val_recall_1'], label='Validation Recall')
    plt.title('Recall over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_lstm_training_history(lstm_history)

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c

#Complete here

# Load genre labels
genre_df = pd.read_csv("/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv")
genre_labels = list(genre_df.columns[2:-1])  # Skip 'ID' and 'Genre' columns
print("Genre labels:", genre_labels)

# Load the best weights
cnn_model.load_weights("/content/checkpoint_cnn.weights.h5")
lstm_model.load_weights("/content/checkpoint_lstm.weights.h5")

# Get the batches
poster_batch = next(iter(posters_valid_ds))
overview_batch = next(iter(overviews_valid_ds))
poster_images, poster_labels = poster_batch
overview_texts, overview_labels = overview_batch

# Get the Prediction
cnn_preds = cnn_model.predict(poster_images)
lstm_preds = lstm_model.predict(overview_texts)
cnn_binary = (cnn_preds >= 0.5).astype(int)
lstm_binary = (lstm_preds >= 0.5).astype(int)
true_labels = poster_labels.numpy().astype(int)

os.makedirs("report_examples", exist_ok=True)

# Visulaize Examples (Get 10)
for i in range(10):
    plt.figure(figsize=(8, 6))

    #Plot poster Examples
    plt.subplot(2, 1, 1)
    plt.imshow(poster_images[i].numpy())
    plt.axis('off')
    plt.title(f"Example {i+1} - Poster")

    #Get overview
    try:
        overview = overview_texts[i].numpy().decode('utf-8')
    except:
        overview = str(overview_texts[i].numpy())
    wrapped_overview = "\n".join(textwrap.wrap(overview, width=100))

    #Get True genres
    true_genres = [genre_labels[j] for j, val in enumerate(true_labels[i]) if val == 1]

    # Top-3 predicted genres
    top3_cnn_idx = np.argsort(cnn_preds[i])[::-1][:3]
    top3_lstm_idx = np.argsort(lstm_preds[i])[::-1][:3]
    cnn_top = [genre_labels[j] for j in top3_cnn_idx]
    lstm_top = [genre_labels[j] for j in top3_lstm_idx]
    cnn_vals = cnn_preds[i][top3_cnn_idx]
    lstm_vals = lstm_preds[i][top3_lstm_idx]

    # Bar chart
    plt.subplot(2, 1, 2)
    width = 0.35
    y_pos = np.arange(3)
    plt.barh(y_pos - width/2, cnn_vals, width, color='blue', label='CNN')
    plt.barh(y_pos + width/2, lstm_vals, width, color='orange', label='LSTM')
    plt.yticks(y_pos, cnn_top)
    plt.xlabel("Confidence Score")
    plt.title(f"Top-3 Genre Predictions - Example {i+1}")
    plt.legend()

    plt.tight_layout()
    plt.savefig(f"report_examples/example_{i+1}_plot.png")
    plt.show()

    print(f"\n🎬 Example {i+1}")
    print("📜 Overview:")
    print(wrapped_overview)
    print(f"\n✅ True Genres:        {', '.join(true_genres)}")

    cnn_result = [f"{g} ✅" if g in true_genres else f"{g} ❌" for g in cnn_top]
    lstm_result = [f"{g} ✅" if g in true_genres else f"{g} ❌" for g in lstm_top]
    print(f"🔵 Top-3 CNN Genres:   {', '.join(cnn_result)}")
    print(f"🟠 Top-3 LSTM Genres:  {', '.join(lstm_result)}")

    cnn_missed = [g for g in true_genres if g not in cnn_top]
    lstm_missed = [g for g in true_genres if g not in lstm_top]

    print("🔍 Missed Predictions:")
    print(f"   CNN missed:  {', '.join(cnn_missed) if cnn_missed else 'None ✅'}")
    print(f"   LSTM missed: {', '.join(lstm_missed) if lstm_missed else 'None ✅'}")
    print("-" * 100)
# Out:
# Genre labels: ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'N/A', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Short', 'Sport', 'Thriller', 'War', 'Western']
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 🎬 Example 1
# 📜 Overview:
# Three blue-collar acquaintances come across millions of dollars in lost cash and make a plan to keep
# their find from the authorities, but it isn't long before complications and mistrust weave their way
# into the plan.
#
# ✅ True Genres:        Crime, Drama, Thriller
# 🔵 Top-3 CNN Genres:   Drama ✅, Thriller ✅, Crime ✅
# 🟠 Top-3 LSTM Genres:  Drama ✅, Action ❌, Comedy ❌
# 🔍 Missed Predictions:
#    CNN missed:  None ✅
#    LSTM missed: Crime, Thriller
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 2
# 📜 Overview:
# A woman hires a drifter as her guide through New Orleans in search of her father, who has gone
# missing. They discover a deadly game of cat and mouse behind his disappearance in the process.
#
# ✅ True Genres:        Action, Thriller
# 🔵 Top-3 CNN Genres:   Drama ❌, Action ✅, Comedy ❌
# 🟠 Top-3 LSTM Genres:  Drama ❌, Comedy ❌, Action ✅
# 🔍 Missed Predictions:
#    CNN missed:  Thriller
#    LSTM missed: Thriller
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 3
# 📜 Overview:
# All all-female gang of Old West bank robbers comes out of retirement to rescue a sister in peril.
#
# ✅ True Genres:        Action, Drama, Western
# 🔵 Top-3 CNN Genres:   Drama ✅, Action ✅, Crime ❌
# 🟠 Top-3 LSTM Genres:  Drama ✅, Comedy ❌, Romance ❌
# 🔍 Missed Predictions:
#    CNN missed:  Western
#    LSTM missed: Action, Western
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 4
# 📜 Overview:
# A young female landowner in 1840s Jamaica marries a just-arrived Englishman to avoid losing her
# property. All seems to be perfect, love arises, and happiness is on the way, but she is ...
#
# ✅ True Genres:        Drama, Romance, Thriller
# 🔵 Top-3 CNN Genres:   Drama ✅, Crime ❌, Romance ✅
# 🟠 Top-3 LSTM Genres:  Drama ✅, Comedy ❌, Romance ✅
# 🔍 Missed Predictions:
#    CNN missed:  Thriller
#    LSTM missed: Thriller
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 5
# 📜 Overview:
# From start to finish, it's a story of friendship between four street-wise males who don't mind using
# violence to achieve the lives that they want. They trust no one but each other, which is vital to
# their success as mobsters.
#
# ✅ True Genres:        Crime, Drama
# 🔵 Top-3 CNN Genres:   Drama ✅, Action ❌, Crime ✅
# 🟠 Top-3 LSTM Genres:  Drama ✅, Comedy ❌, Romance ❌
# 🔍 Missed Predictions:
#    CNN missed:  None ✅
#    LSTM missed: Crime
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 6
# 📜 Overview:
# A former gangster fresh out of prison wants to change his life for the better and must save his 10
# year old son who has already chosen a gang life.
#
# ✅ True Genres:        Crime, Drama
# 🔵 Top-3 CNN Genres:   Drama ✅, Thriller ❌, Crime ✅
# 🟠 Top-3 LSTM Genres:  Drama ✅, Comedy ❌, Romance ❌
# 🔍 Missed Predictions:
#    CNN missed:  None ✅
#    LSTM missed: Crime
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 7
# 📜 Overview:
# A soon to be divorced Beverly Hills socialite is determined to prove to her husband and herself that
# she can finish what she starts out to do, by becoming a den mother to a troop of Beverly Hills Girl
# Scouts.
#
# ✅ True Genres:        Adventure, Comedy
# 🔵 Top-3 CNN Genres:   Comedy ✅, Drama ❌, Action ❌
# 🟠 Top-3 LSTM Genres:  Drama ❌, Comedy ✅, Romance ❌
# 🔍 Missed Predictions:
#    CNN missed:  Adventure
#    LSTM missed: Adventure
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 8
# 📜 Overview:
# Mysterious reclusive magician the Great Zamboni and his pet jaguar Shadow reside in the Spooky
# House, an old mansion that's rigged with magic tricks and hidden chambers. Young orphan Max ...
#
# ✅ True Genres:        Family
# 🔵 Top-3 CNN Genres:   Drama ❌, Action ❌, Comedy ❌
# 🟠 Top-3 LSTM Genres:  Drama ❌, Comedy ❌, Action ❌
# 🔍 Missed Predictions:
#    CNN missed:  Family
#    LSTM missed: Family
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 9
# 📜 Overview:
# Martin Bonner has just moved to Nevada from the East Coast, leaving behind his two adult children
# and a life he spent more than two decades building.
#
# ✅ True Genres:        Drama
# 🔵 Top-3 CNN Genres:   Drama ✅, Romance ❌, Thriller ❌
# 🟠 Top-3 LSTM Genres:  Drama ✅, Comedy ❌, Romance ❌
# 🔍 Missed Predictions:
#    CNN missed:  None ✅
#    LSTM missed: None ✅
# ----------------------------------------------------------------------------------------------------
# 🎬 Example 10
# 📜 Overview:
# A champion high school cheerleading squad discovers its previous captain stole all their best
# routines from an inner-city school and must scramble to compete at this year's championships.
#
# ✅ True Genres:        Comedy, Sport
# 🔵 Top-3 CNN Genres:   Drama ❌, Romance ❌, Comedy ✅
# 🟠 Top-3 LSTM Genres:  Drama ❌, Comedy ✅, Romance ❌
# 🔍 Missed Predictions:
#    CNN missed:  Sport
#    LSTM missed: Sport
# ----------------------------------------------------------------------------------------------------
